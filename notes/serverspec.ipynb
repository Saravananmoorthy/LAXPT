# %%
# !rake -T --all
# Out:
# (in /Users/jayeola/projects/LAXPT)
# rake default       #
# rake spec          #
# rake spec:all      #
# rake spec:default  #
# rake spec:uxpm00   # Run serverspec tests to uxpm00

# %%
# !rake spec
# Out:
# (in /Users/jayeola/projects/LAXPT)
# /System/Library/Frameworks/Ruby.framework/Versions/2.0/usr/bin/ruby -I/Users/jayeola/.gem/ruby/2.0.0/gems/rspec-support-3.4.1/lib:/Users/jayeola/.gem/ruby/2.0.0/gems/rspec-core-3.4.4/lib /Users/jayeola/.gem/ruby/2.0.0/gems/rspec-core-3.4.4/exe/rspec --pattern spec/uxpm00/\*_spec.rb
#
#
#
# templatedir=$confdir/templates << test line not there!!
#
#
# File "/etc/hosts"
#   should exist
#   should be file
#   content
#     should match /puppet.vm.local / (FAILED - 1)
#   content
#     should match /puppet.vm.local / (FAILED - 2)
#   content
#     should match /127.0.0.1	localhost/
#   content
#     should match /127.0.0.1	puppet/ (FAILED - 3)
#   content
#     should match /1.2.3.4  puppet.vm.local / (FAILED - 4)
#
# Package "puppetmaster"
#   should be installed
#
# Package "ntp"
#   should be installed
#
# Package "nmap"
#   should be installed
#
# Port "8140"
#   should be listening
#
# Service "puppetmaster"
#   should be enbled (FAILED - 5)
# ...
